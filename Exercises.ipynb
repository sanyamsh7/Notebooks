# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyamsh7/Notebooks/blob/main/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn

sklearn.__version__
# Out:
# '1.0.2'

# %%
import numpy as np
import pandas as pd


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
df.isna()
# Out:
#     size  color  gender  price  weight  bought
# 0  False  False   False  False   False   False
# 1  False  False   False  False   False   False
# 2  False  False    True   True   False   False
# 3   True  False   False  False    True   False
# 4  False  False   False  False   False   False
# 5  False  False   False  False    True   False

# %%
np.round(df.isna().sum()/df.shape[0], 2)
# Out:
# size      0.17
# color     0.00
# gender    0.17
# price     0.17
# weight    0.33
# bought    0.00
# dtype: float64

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df = pd.DataFrame(data=data)

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
imp_mean = SimpleImputer(missing_values = np.nan, strategy = 'mean')

# %%
df[['weight']] = imp_mean.fit_transform(df[['weight']])

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0   415.0     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0   415.0     no

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df = pd.DataFrame(data=data)
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
df[['weight']] = imputer.fit_transform(df[['weight']])

# %%
imputer.statistics_[0]   # to find the value which was imputed by the simple imputer
# Out:
# array([415.])

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df = pd.DataFrame(data=data)

# %%
# replace / impute with a constant value 
impute = SimpleImputer(fill_value=99.0, strategy = 'constant')
df[['price']] = impute.fit_transform(df[['price']])
print(df)
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN   99.0   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df = pd.DataFrame(data=data)

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
# fill in for most frequent value in size column
impute = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
df[['size']] = impute.fit_transform(df[['size']])
print(df)
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3    M  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df = pd.DataFrame(data=data)

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
data = df[~df.weight.isna()] 
col = [column for column in data.columns if data[column].dtype != 'O']
print(data[col].mean())
# Out:
# price     122.333333
# weight    415.000000
# dtype: float64

# %%
# or 
print(df[~df['weight'].isnull()].mean())
# Out:
# price     122.333333
# weight    415.000000
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer


data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df = pd.DataFrame(data=data)

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
col = [column for column in df.columns if df[column].dtype == 'O']
col
# Out:
# ['size', 'color', 'gender', 'bought']

# %%
df_object = df[col]
impute = SimpleImputer(missing_values=np.nan, strategy = 'constant', fill_value='empty')
df_object = pd.DataFrame(impute.fit_transform(df_object))

# %%
df_object.columns = col

# %%
print(df_object)
# Out:
#     size  color  gender bought
# 0     XL    red  female    yes
# 1      L  green    male     no
# 2      M   blue   empty    yes
# 3  empty  green  female     no
# 4      M    red  female    yes
# 5      M  green    male     no

# %%
# OR 
df_object = df.select_dtypes(include = ['object']).fillna('empty'
)

# %%
df_object
# Out:
#     size  color  gender bought
# 0     XL    red  female    yes
# 1      L  green    male     no
# 2      M   blue   empty    yes
# 3  empty  green  female     no
# 4      M    red  female    yes
# 5      M  green    male     no

# %%
import pandas as pd


df = pd.DataFrame(data={'weight': [75., 78.5, 85., 91., 84.5, 83., 68.]})

# discretize the weight column . divide the values of this column to three intervals of equal width.
pd.cut(df.weight, 3)   # discretize into 3 equal size bins
# Out:
# 0    (67.977, 75.667]
# 1    (75.667, 83.333]
# 2      (83.333, 91.0]
# 3      (83.333, 91.0]
# 4      (83.333, 91.0]
# 5    (75.667, 83.333]
# 6    (67.977, 75.667]
# Name: weight, dtype: category
# Categories (3, interval[float64, right]): [(67.977, 75.667] < (75.667, 83.333] < (83.333, 91.0]]

# %%
import pandas as pd


df = pd.DataFrame(data={'weight': [75., 78.5, 85., 91., 84.5, 83., 68.]})

df
# Out:
#    weight
# 0    75.0
# 1    78.5
# 2    85.0
# 3    91.0
# 4    84.5
# 5    83.0
# 6    68.0

# %%
df['weight_cut'] = pd.cut(df.weight, bins = (60,75,80,95))
print(df)
# Out:
#    weight weight_cut
# 0    75.0   (60, 75]
# 1    78.5   (75, 80]
# 2    85.0   (80, 95]
# 3    91.0   (80, 95]
# 4    84.5   (80, 95]
# 5    83.0   (80, 95]
# 6    68.0   (60, 75]

# %%
df = pd.DataFrame(data={'weight': [75., 78.5, 85., 91., 84.5, 83., 68.]})
df
# Out:
#    weight
# 0    75.0
# 1    78.5
# 2    85.0
# 3    91.0
# 4    84.5
# 5    83.0
# 6    68.0

# %%
df['weight_cut'] = pd.cut(df.weight, bins = (60,75,80,95), labels = ['light', 'normal', 'heavy'])
print(df)
# Out:
#    weight weight_cut
# 0    75.0      light
# 1    78.5     normal
# 2    85.0      heavy
# 3    91.0      heavy
# 4    84.5      heavy
# 5    83.0      heavy
# 6    68.0      light

# %%
import pandas as pd


df = pd.DataFrame(data={'weight': [75., 78.5, 85., 91., 84.5, 83., 68.]})
df['weight_cut'] = pd.cut(df['weight'], bins=(60, 75, 80, 95), labels=['light', 'normal', 'heavy'])
df
# Out:
#    weight weight_cut
# 0    75.0      light
# 1    78.5     normal
# 2    85.0      heavy
# 3    91.0      heavy
# 4    84.5      heavy
# 5    83.0      heavy
# 6    68.0      light

# %%
pd.get_dummies(df)
# Out:
#    weight  weight_cut_light  weight_cut_normal  weight_cut_heavy
# 0    75.0                 1                  0                 0
# 1    78.5                 0                  1                 0
# 2    85.0                 0                  0                 1
# 3    91.0                 0                  0                 1
# 4    84.5                 0                  0                 1
# 5    83.0                 0                  0                 1
# 6    68.0                 1                  0                 0

# %%
data_dict = {
    'currency': [['PLN', 'USD'], ['EUR', 'USD', 'PLN', 'CAD'], ['GBP'], ['JPY', 'CZK', 'HUF'], []]
}
df = pd.DataFrame(data=data_dict)
df
# Out:
#                currency
# 0            [PLN, USD]
# 1  [EUR, USD, PLN, CAD]
# 2                 [GBP]
# 3       [JPY, CZK, HUF]
# 4                    []

# %%
# add new column with lenght of currency list for each row
df['number'] = df['currency'].apply(len)
print(df)
# Out:
#                currency  number
# 0            [PLN, USD]       2
# 1  [EUR, USD, PLN, CAD]       4
# 2                 [GBP]       1
# 3       [JPY, CZK, HUF]       3
# 4                    []       0

# %%
df['currency']
# Out:
# 0              [PLN, USD]
# 1    [EUR, USD, PLN, CAD]
# 2                   [GBP]
# 3         [JPY, CZK, HUF]
# 4                      []
# Name: currency, dtype: object

# %%
df[[
    'currency'
]]
# Out:
#                currency
# 0            [PLN, USD]
# 1  [EUR, USD, PLN, CAD]
# 2                 [GBP]
# 3       [JPY, CZK, HUF]
# 4                    []

# %%
import pandas as pd


data_dict = {
    'currency': [['PLN', 'USD'], ['EUR', 'USD', 'PLN', 'CAD'], ['GBP'], ['JPY', 'CZK', 'HUF'], []]
}
df = pd.DataFrame(data=data_dict)
df
# Out:
#                currency
# 0            [PLN, USD]
# 1  [EUR, USD, PLN, CAD]
# 2                 [GBP]
# 3       [JPY, CZK, HUF]
# 4                    []

# %%
df['PLN_flag'] = df.currency.apply(lambda row: 1 if 'PLN' in row else 0)
df
# Out:
#                currency  PLN_flag
# 0            [PLN, USD]         1
# 1  [EUR, USD, PLN, CAD]         1
# 2                 [GBP]         0
# 3       [JPY, CZK, HUF]         0
# 4                    []         0

# %%
df = pd.DataFrame(data={'hashtags': ['#good#vibes', '#hot#summer#holiday', '#street#food', '#workout']})

# %%
df
# Out:
#               hashtags
# 0          #good#vibes
# 1  #hot#summer#holiday
# 2         #street#food
# 3             #workout

# %%
df_hash = df.hashtags.str.split("#", expand = True).drop(columns =[0])

# %%
df_hash.columns = ['hashtag1', 'hashtag2', 'hashtag3']
print(df_hash)
# Out:
#   hashtag1 hashtag2 hashtag3
# 0     good    vibes     None
# 1      hot   summer  holiday
# 2   street     food     None
# 3  workout     None     None

# %%
df_hash.columns[0]
# Out:
# 0

# %%
import pandas as pd


df = pd.DataFrame(data={'hashtags': ['#good#vibes', '#hot#summer#holiday', '#street#food', '#workout']})
df = df['hashtags'].str.split('#', expand=True)
df = df.drop(columns=[0])
df.columns = ['hashtag1', 'hashtag2', 'hashtag3']
df
# Out:
#   hashtag1 hashtag2 hashtag3
# 0     good    vibes     None
# 1      hot   summer  holiday
# 2   street     food     None
# 3  workout     None     None

# %%
df['missing'] = df.isnull().sum(axis=1)

# %%
df
# Out:
#   hashtag1 hashtag2 hashtag3  missing
# 0     good    vibes     None        1
# 1      hot   summer  holiday        0
# 2   street     food     None        1
# 3  workout     None     None        2
